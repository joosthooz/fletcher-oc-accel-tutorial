# %% [markdown]
# # OpenCAPI course lab3, using Fletcher with oc-accel
#
# In this lab, we will demonstrate how to use Fletcher in the oc-accel acceleration environment.
# Fletcher is a framework that will allow you to connect an FPGA accelerator to any big data analytics framework/application based on Apache Arrow.
#
# In this notebook we assume you are running from the virtual machine that is provided with the course, and have already run the installation script.
# If you wish to run the notebook from a different environment, you need to install the dependencies yourself, modify the paths, and perform the necessary configurations.

# %% [markdown]
# # Overview of Fletcher
# Fletcher is a framework that creates an easy-to-use interface on both the hardware side and the software side.
# It works by generating hardware interfaces based on a "schema", which is the layout of the data in your big data analytics application.
#
# ![Fletcher overview](https://github.com/abs-tudelft/fletcher/raw/develop/fletcher.svg)
#
# Important to realize is that in most cases, a set of interfaces generated by Fletcher will not work if the schema changes.
# In that case, new interfaces need to be generated and the accelerator design needs to be adapted.
# Fletcher targets long-running workloads were the data layout does not frequently change, because these are the types of workload that warrant the design of an accelerator (in other words, if you do not know that your application will run for a very long time and the data layout will stay the same, you would not create an accelerator for it).
#
#
# ## Components
# Fletcher consists of several components;
# - Hardware generator cerata
# - Hardware library vhdlib that includes several basic hardware components such as FIFOs
# - Software runtime that provides the fletcher API to user applications
# - Examples
#
# ## Documentation
# Find the Fletcher documentation on the [main github page](https://github.com/abs-tudelft/fletcher).
#
#
# ## Installation
# As stated, we assume you are running the VM provided by the OpenCAPI course and have run the installation procedure from [this repository](https://github.com/joosthooz/fletcher-oc-accel-installscripts), which is included in [the course toplevel repository](https://github.com/abs-tudelft/opencapicourse_toplevel).

# %% [markdown]
# # Fletcher sum example
# First, follow [the sum example tutorial](https://github.com/abs-tudelft/fletcher/blob/develop/examples/sum/README.md)

# %%
import os
#WORKSPACE="/home/opencapi/workspace"
WORKSPACE="/home/jjhoozemans/workspaces/openCAPI/course/workspace"
ocaccel_path=os.path.join(WORKSPACE, "OpenCAPI/oc-accel")
fletcher_ocaccel_path=os.path.join(WORKSPACE, "OpenCAPI/fletcher-oc-accel")
ocaccel_defconfig_path=os.path.join(ocaccel_path, "defconfig/")

# Add the configuration file we have prepared for this lab to oc-accel
# !cp customaction.defconfig {ocaccel_defconfig_path}
# !cp sum_snap_env.sh {ocaccel_path}/snap_env.sh

# %%
# In this example, we run fletcher sum example using oc-accel
# Go into the oc-accel working directory
# %cd {ocaccel_path}

# !make -s customaction.defconfig && ./ocaccel_workflow.py --no_configure -t {fletcher_ocaccel_path}/examples/sum/sw/run_ocxl_cosim_notebook.sh
# Out:
# /home/jjhoozemans/workspaces/openCAPI/course/workspace/OpenCAPI/oc-accel
# #
# # configuration written to config
# #
# Generating SNAP config files /home/jjhoozemans/workspaces/openCAPI/course/workspace/OpenCAPI/oc-accel/.snap_config, /home/jjhoozemans/workspaces/openCAPI/course/workspace/OpenCAPI/oc-accel/.snap_config.sh and /home/jjhoozemans/workspaces/openCAPI/course/workspace/OpenCAPI/oc-accel/.snap_config.cflags ...
# Generation of SNAP config files done.
#
# [CLEAN ENVIRONMENT...] start 11:44:26 Thu Oct 21 2021
# =======================================================
# == OC-ACCEL ENVIRONMENT SETUP                        ==
# =======================================================
# Path to vivado          is set to: /opt/Xilinx/Vivado/2019.1/bin/vivado
# Vivado version          is set to: Vivado v2019.1 (64-bit)
# HLS tool                is set to: Vivado(TM) HLS - High-Level Synthesis from C, C++ and SystemC v2019.1 (64-bit)
# =====Simulation setup: Setting up OCSE version==========
# =====Simulation setup: Checking path to OCSE==========
# OCSE_ROOT              is set to: "/home/jjhoozemans/workspaces/openCAPI/course/workspace/OpenCAPI/oc-accel/../ocse"
# =====ACTION ROOT setup=================================
# ACTION_ROOT             is set to: "/home/jjhoozemans/workspaces/openCAPI/course/workspace/OpenCAPI/oc-accel/../fletcher-oc-accel/examples/sum"
# =====Timing limit for FPGA image build in ps============
# TIMING_LABLIMIT         is set to: "-200"
# =======================================================
#
# =====Content of snap_env.sh============================
# export ACTION_ROOT=/home/jjhoozemans/workspaces/openCAPI/course/workspace/OpenCAPI/oc-accel/../fletcher-oc-accel/examples/sum
# export TIMING_LABLIMIT="-200"
# export ILA_SETUP_FILE=
# export OCSE_ROOT=/home/jjhoozemans/workspaces/openCAPI/course/workspace/OpenCAPI/oc-accel/../ocse
# export XILINXD_LICENSE_FILE=point_me_to_a_license_if_you_want_to_synthesize_a_bitstream
# =======================================================
#
#   Suggested next step: to run a simulation,      execute: make sim
#                     or to build the FPGA binary, execute: make image
# --------> WELCOME to IBM OpenCAPI Acceleration Framework
# --------> Environment Check
# gcc	 installed as	/usr/bin/gcc
# vivado	 installed as	/opt/Xilinx/Vivado/2019.1/bin/vivado
# xterm	 installed as	/usr/bin/xterm
# OCSE path /home/jjhoozemans/workspaces/openCAPI/course/workspace/OpenCAPI/ocse is valid
# SNAP ROOT /home/jjhoozemans/workspaces/openCAPI/course/workspace/OpenCAPI/oc-accel is valid
# Environment check PASSED
# --------> Make the simulation model
# Runnig ... check ./ocaccel_workflow.make_model.log for details of full progress
# FINISHED! - [=============================] 100%============ ] 96%
#
# SNAP simulation model generated
# Setup simulation for xsim
# Simulation run dir: /home/jjhoozemans/workspaces/openCAPI/course/workspace/OpenCAPI/oc-accel/hardware/sim/xsim/1634809658800.3017914913
# --------> Simulation Session
# SNAP ROOT	 /home/jjhoozemans/workspaces/openCAPI/course/workspace/OpenCAPI/oc-accel
# ACTION ROOT	 /home/jjhoozemans/workspaces/openCAPI/course/workspace/OpenCAPI/oc-accel/../fletcher-oc-accel/examples/sum
# SIMULATOR	 xsim
# SIMOUT PATH	 /home/jjhoozemans/workspaces/openCAPI/course/workspace/OpenCAPI/oc-accel/hardware/sim/xsim/1634809658800.3017914913
# OCSE_ROOT	 /home/jjhoozemans/workspaces/openCAPI/course/workspace/OpenCAPI/ocse
# Testcase cmd:	 source
# Testcase args:	 /home/jjhoozemans/python_venvs/fletcher_updated/bin/activate && /home/jjhoozemans/workspaces/openCAPI/course/workspace/OpenCAPI/fletcher-oc-accel/examples/sum/sw/run_ocxl_cosim_notebook.sh
# Simulator running on process ID 12831
# Waiting for simulator running!
# [=============================] 100%
#  Simulator running successfully on socket: tud211698.ws.tudelft.net:32768
# OCSE running with pid 12893
# [=============================] 100%
#  OCSE listening on socket: tud211698.ws.tudelft.net:16384
# --------> Running testcase source
# Traceback (most recent call last):
#   File "./ocaccel_workflow.py", line 197, in <module>
#     sim.run()
#   File "/home/jjhoozemans/workspaces/openCAPI/course/workspace/OpenCAPI/oc-accel/scripts/ide/run_sim.py", line 78, in run
#     self.testcase.run()
#   File "/home/jjhoozemans/workspaces/openCAPI/course/workspace/OpenCAPI/oc-accel/scripts/ide/run_sim.py", line 416, in run
#     rc = run_and_poll(cmd = cmd, work_dir = self.simout, log = self.test_log)
#   File "/home/jjhoozemans/workspaces/openCAPI/course/workspace/OpenCAPI/oc-accel/scripts/ide/ocaccel_utils.py", line 150, in run_and_poll
#     stdout=f, stderr=f)
#   File "/usr/lib64/python2.7/subprocess.py", line 394, in __init__
#     errread, errwrite)
#   File "/usr/lib64/python2.7/subprocess.py", line 1047, in _execute_child
#     raise child_exception
# OSError: [Errno 2] No such file or directory
# Killing OCSE pid 12893

# %%
# !cat {fletcher_ocaccel_path}/examples/sum/sw/run_ocxl_cosim_notebook.sh.log
# Out:
# /usr/bin/python: No module named notebook
